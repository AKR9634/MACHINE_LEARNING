# %%
import requests

# %%
payload = {'key1' : 'value1', 'key2' : 'value2'}
r = requests.get('https://httpbin.org/get', params = payload)

# %%
print(r.url)
# Out:
# https://httpbin.org/get?key1=value1&key2=value2

# %%
r = requests.get('https://api.github.com/events')

# %%
r.text
# Out:
# '[{"id":"52524724528","type":"WatchEvent","actor":{"id":95643831,"login":"Faysal3010","display_login":"Faysal3010","gravatar_id":"","url":"https://api.github.com/users/Faysal3010","avatar_url":"https://avatars.githubusercontent.com/u/95643831?"},"repo":{"id":951302596,"name":"therealthapa/case2025-multimodal","url":"https://api.github.com/repos/therealthapa/case2025-multimodal"},"payload":{"action":"started"},"public":true,"created_at":"2025-07-25T02:17:21Z"},{"id":"52524724419","type":"PushEvent","actor":{"id":768790,"login":"ervwalter","display_login":"ervwalter","gravatar_id":"","url":"https://api.github.com/users/ervwalter","avatar_url":"https://avatars.githubusercontent.com/u/768790?"},"repo":{"id":323510718,"name":"ervwalter/trendweight","url":"https://api.github.com/repos/ervwalter/trendweight"},"payload":{"repository_id":323510718,"push_id":25714272687,"size":2,"distinct_size":1,"ref":"refs/heads/release-please--branches--main","head":"c43fd62ebcc98948c5d31d73d24024217538f25c","before":"7a609e9597148ab88d113160fad0f89664f58eba","commits":[{"sha":"09c88f940e04b8afd73f381601ebd5831153e1bd","author":{"email":"29139614+renovate[bot]@users.noreply.github.com","name":"renovate[bot]"},"message":"deps: update npm dependencies (#270)\\n\\nCo-authored-by: renovate[bot] <29139614+renovate[bot]@users.noreply.github.com>","distinct":false,"url":"https://api.github.com/repos/ervwalter/trendweight/commits/09c88f940e04b8afd73f381601ebd5831153e1bd"},{"sha":"c43fd62ebcc98948c5d31d73d24024217538f25c","author":{"email":"erv@ewal.net","name":"Erv Walter"},"message":"chore(main): release 2.2.0","distinct":true,"url":"https://api.github.com/repos/ervwalter/trendweight/commits/c43fd62ebcc98948c5d31d73d24024217538f25c"}]},"public":true,"created_at":"2025-07-25T02:17:21Z"},{"id":"52524724410","type":"PushEvent","actor":{"id":80912876,"login":"yutaro-sakamoto","display_login":"yutaro-sakamoto","gravatar_id":"","url":"https://api.github.com/users/yutaro-sakamoto","avatar_url":"https://avatars.githubusercontent.com/u/80912876?"},"repo":{"id":276063468,"name":"opensourcecobol/opensourcecobol4j","url":"https://api.github.com/repos/opensourcecobol/opensourcecobol4j"},"payload":{"repository_id":276063468,"push_id":25714272685,"size":1,"distinct_size":1,"ref":"refs/heads/develop","head":"48e1c40bb8426b6d27064d51fc6a67d772956bd6","before":"bd3463cfb44ecd8d4c3537a048e69614a40b550e","commits":[{"sha":"48e1c40bb8426b6d27064d51fc6a67d772956bd6","author":{"email":"80912876+yutaro-sakamoto@users.noreply.github.com","name":"yutaro-sakamoto"},"message":"Release 1.1.11 (#683)","distinct":true,"url":"https://api.github.com/repos/opensourcecobol/opensourcecobol4j/commits/48e1c40bb8426b6d27064d51fc6a67d772956bd6"}]},"public":true,"created_at":"2025-07-25T02:17:21Z","org":{"id":5718549,"login":"opensourcecobol","gravatar_id":"","url":"https://api.github.com/orgs/opensourcecobol","avatar_url":"https://avatars.githubusercontent.com/u/5718549?"}},{"id":"52524724325","type":"PushEvent","actor":{"id":53819671,"login":"Jigubkmn","display_login":"Jigubkmn","gravatar_id":"","url":"https://api.github.com/users/Jigubkmn","avatar_url":"https://avatars.githubusercontent.com/u/53819671?"},"repo":{"id":1005699206,"name":"Jigubkmn/diaryApp","url":"https://api.github.com/repos/Jigubkmn/diaryApp"},"payload":{"repository_id":1005699206,"push_id":25714272684,"size":1,"distinct_size":1,"ref":"refs/heads/feature/mental_health_check","head":"adb757eccfe674034b264be3a4814c66ed0033af","before":"7b3e42c84402025079d3302868e7b71652c0e61f","commits":[{"sha":"adb757eccfe674034b264be3a4814c66ed0033af","author":{"email":"bkmn.31519@gmail.com","name":"Masashi Shiomi"},"message":"計算結果によって出力内容を変更","distinct":true,"url":"https://api.github.com/repos/Jigubkmn/diaryApp/commits/adb757eccfe674034b264be3a4814c66ed0033af"}]},"public":true,"created_at":"2025-07-25T02:17:21Z"},{"id":"52524724223","type":"PushEvent","actor":{"id":87141165,"login":"trunk-staging-io[bot]","display_login":"trunk-staging-io","gra ...

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r.encoding = 'ISO-8859-1'

# %%
r.text
# Out:
# '[{"id":"52524724528","type":"WatchEvent","actor":{"id":95643831,"login":"Faysal3010","display_login":"Faysal3010","gravatar_id":"","url":"https://api.github.com/users/Faysal3010","avatar_url":"https://avatars.githubusercontent.com/u/95643831?"},"repo":{"id":951302596,"name":"therealthapa/case2025-multimodal","url":"https://api.github.com/repos/therealthapa/case2025-multimodal"},"payload":{"action":"started"},"public":true,"created_at":"2025-07-25T02:17:21Z"},{"id":"52524724419","type":"PushEvent","actor":{"id":768790,"login":"ervwalter","display_login":"ervwalter","gravatar_id":"","url":"https://api.github.com/users/ervwalter","avatar_url":"https://avatars.githubusercontent.com/u/768790?"},"repo":{"id":323510718,"name":"ervwalter/trendweight","url":"https://api.github.com/repos/ervwalter/trendweight"},"payload":{"repository_id":323510718,"push_id":25714272687,"size":2,"distinct_size":1,"ref":"refs/heads/release-please--branches--main","head":"c43fd62ebcc98948c5d31d73d24024217538f25c","before":"7a609e9597148ab88d113160fad0f89664f58eba","commits":[{"sha":"09c88f940e04b8afd73f381601ebd5831153e1bd","author":{"email":"29139614+renovate[bot]@users.noreply.github.com","name":"renovate[bot]"},"message":"deps: update npm dependencies (#270)\\n\\nCo-authored-by: renovate[bot] <29139614+renovate[bot]@users.noreply.github.com>","distinct":false,"url":"https://api.github.com/repos/ervwalter/trendweight/commits/09c88f940e04b8afd73f381601ebd5831153e1bd"},{"sha":"c43fd62ebcc98948c5d31d73d24024217538f25c","author":{"email":"erv@ewal.net","name":"Erv Walter"},"message":"chore(main): release 2.2.0","distinct":true,"url":"https://api.github.com/repos/ervwalter/trendweight/commits/c43fd62ebcc98948c5d31d73d24024217538f25c"}]},"public":true,"created_at":"2025-07-25T02:17:21Z"},{"id":"52524724410","type":"PushEvent","actor":{"id":80912876,"login":"yutaro-sakamoto","display_login":"yutaro-sakamoto","gravatar_id":"","url":"https://api.github.com/users/yutaro-sakamoto","avatar_url":"https://avatars.githubusercontent.com/u/80912876?"},"repo":{"id":276063468,"name":"opensourcecobol/opensourcecobol4j","url":"https://api.github.com/repos/opensourcecobol/opensourcecobol4j"},"payload":{"repository_id":276063468,"push_id":25714272685,"size":1,"distinct_size":1,"ref":"refs/heads/develop","head":"48e1c40bb8426b6d27064d51fc6a67d772956bd6","before":"bd3463cfb44ecd8d4c3537a048e69614a40b550e","commits":[{"sha":"48e1c40bb8426b6d27064d51fc6a67d772956bd6","author":{"email":"80912876+yutaro-sakamoto@users.noreply.github.com","name":"yutaro-sakamoto"},"message":"Release 1.1.11 (#683)","distinct":true,"url":"https://api.github.com/repos/opensourcecobol/opensourcecobol4j/commits/48e1c40bb8426b6d27064d51fc6a67d772956bd6"}]},"public":true,"created_at":"2025-07-25T02:17:21Z","org":{"id":5718549,"login":"opensourcecobol","gravatar_id":"","url":"https://api.github.com/orgs/opensourcecobol","avatar_url":"https://avatars.githubusercontent.com/u/5718549?"}},{"id":"52524724325","type":"PushEvent","actor":{"id":53819671,"login":"Jigubkmn","display_login":"Jigubkmn","gravatar_id":"","url":"https://api.github.com/users/Jigubkmn","avatar_url":"https://avatars.githubusercontent.com/u/53819671?"},"repo":{"id":1005699206,"name":"Jigubkmn/diaryApp","url":"https://api.github.com/repos/Jigubkmn/diaryApp"},"payload":{"repository_id":1005699206,"push_id":25714272684,"size":1,"distinct_size":1,"ref":"refs/heads/feature/mental_health_check","head":"adb757eccfe674034b264be3a4814c66ed0033af","before":"7b3e42c84402025079d3302868e7b71652c0e61f","commits":[{"sha":"adb757eccfe674034b264be3a4814c66ed0033af","author":{"email":"bkmn.31519@gmail.com","name":"Masashi Shiomi"},"message":"è¨\x88ç®\x97çµ\x90æ\x9e\x9cã\x81«ã\x82\x88ã\x81£ã\x81¦å\x87ºå\x8a\x9bå\x86\x85å®¹ã\x82\x92å¤\x89æ\x9b´","distinct":true,"url":"https://api.github.com/repos/Jigubkmn/diaryApp/commits/adb757eccfe674034b264be3a4814c66ed0033af"}]},"public":true,"created_at":"2025-07-25T02:17:21Z"},{"id":"52524724223","type":"PushEvent","actor" ...

# %%
r.json()
# Out:
# [{'id': '52524724528',
#   'type': 'WatchEvent',
#   'actor': {'id': 95643831,
#    'login': 'Faysal3010',
#    'display_login': 'Faysal3010',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Faysal3010',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/95643831?'},
#   'repo': {'id': 951302596,
#    'name': 'therealthapa/case2025-multimodal',
#    'url': 'https://api.github.com/repos/therealthapa/case2025-multimodal'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2025-07-25T02:17:21Z'},
#  {'id': '52524724419',
#   'type': 'PushEvent',
#   'actor': {'id': 768790,
#    'login': 'ervwalter',
#    'display_login': 'ervwalter',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ervwalter',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/768790?'},
#   'repo': {'id': 323510718,
#    'name': 'ervwalter/trendweight',
#    'url': 'https://api.github.com/repos/ervwalter/trendweight'},
#   'payload': {'repository_id': 323510718,
#    'push_id': 25714272687,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/release-please--branches--main',
#    'head': 'c43fd62ebcc98948c5d31d73d24024217538f25c',
#    'before': '7a609e9597148ab88d113160fad0f89664f58eba',
#    'commits': [{'sha': '09c88f940e04b8afd73f381601ebd5831153e1bd',
#      'author': {'email': '29139614+renovate[bot]@users.noreply.github.com',
#       'name': 'renovate[bot]'},
#      'message': 'deps: update npm dependencies (#270)\n\nCo-authored-by: renovate[bot] <29139614+renovate[bot]@users.noreply.github.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/ervwalter/trendweight/commits/09c88f940e04b8afd73f381601ebd5831153e1bd'},
#     {'sha': 'c43fd62ebcc98948c5d31d73d24024217538f25c',
#      'author': {'email': 'erv@ewal.net', 'name': 'Erv Walter'},
#      'message': 'chore(main): release 2.2.0',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ervwalter/trendweight/commits/c43fd62ebcc98948c5d31d73d24024217538f25c'}]},
#   'public': True,
#   'created_at': '2025-07-25T02:17:21Z'},
#  {'id': '52524724410',
#   'type': 'PushEvent',
#   'actor': {'id': 80912876,
#    'login': 'yutaro-sakamoto',
#    'display_login': 'yutaro-sakamoto',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yutaro-sakamoto',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/80912876?'},
#   'repo': {'id': 276063468,
#    'name': 'opensourcecobol/opensourcecobol4j',
#    'url': 'https://api.github.com/repos/opensourcecobol/opensourcecobol4j'},
#   'payload': {'repository_id': 276063468,
#    'push_id': 25714272685,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/develop',
#    'head': '48e1c40bb8426b6d27064d51fc6a67d772956bd6',
#    'before': 'bd3463cfb44ecd8d4c3537a048e69614a40b550e',
#    'commits': [{'sha': '48e1c40bb8426b6d27064d51fc6a67d772956bd6',
#      'author': {'email': '80912876+yutaro-sakamoto@users.noreply.github.com',
#       'name': 'yutaro-sakamoto'},
#      'message': 'Release 1.1.11 (#683)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/opensourcecobol/opensourcecobol4j/commits/48e1c40bb8426b6d27064d51fc6a67d772956bd6'}]},
#   'public': True,
#   'created_at': '2025-07-25T02:17:21Z',
#   'org': {'id': 5718549,
#    'login': 'opensourcecobol',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/opensourcecobol',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5718549?'}},
#  {'id': '52524724325',
#   'type': 'PushEvent',
#   'actor': {'id': 53819671,
#    'login': 'Jigubkmn',
#    'display_login': 'Jigubkmn',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Jigubkmn',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53819671?'},
#   'repo': {'id': 1005699206,
#    'name': 'Jigubkmn/diaryApp',
#    'url': 'https://api.github.com/repos/Jigubkmn/diaryApp'},
#   'payload': {'repository_id': 1005699206,
#    'push_id': 25714272684,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/feature/mental_health_check',
#    'head': 'adb757eccfe674034b264be3a4814c66ed0033af',
#    'before': '7b3e42c84402025079d3302868e7b71652c0e61f',
#    'commits': [{'sha': 'adb757eccfe674034b264be3a4814c66ed0033af',
#      'author': {'email': 'bkmn.31519@gmail.com', 'name': 'Masashi Shiomi'},
#      'message': 'è¨\x88ç®\x97çµ\x90æ\x9e\x9cã\x81«ã\x82\x88ã\x81£ã\x81¦å\x87ºå\x8a\x9bå\x86\x85å®¹ã\x82\x92å¤\x89æ\x9b´',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Jigubkmn/diaryApp/commits/adb757eccfe674034b264be3a4814c66ed0033af'}]},
#   'public': True,
#   'created_at': '2025-07-25T02:17:21Z'},
#  {'id': '52524724223',
#   'type': 'PushEvent',
#   'actor': {'id': 87141165,
#    'login': 'trunk-staging-io[bot]',
#    'display_login': 'trunk-staging-io',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/trunk-staging-io[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/87141165?'},
#   'repo': {'id': 1021130530,
#    'name': 'trunk-io/mergequeue-demo',
#    'url': 'https://api.github.com/repos/trunk-io/mergequeue-demo'},
#   'payload': {'repository_id': 1021130530,
#    'push_id': 25714272597,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/trunk-temp/pr-19931/9b958378-b7e0-4d77-bba5-fec984cdb8a7',
#    'head': 'f9b2fa1f94ee75623f4762c5842ee385eeb66cfd',
#    'before': '7645f247be678da6388a05dec6528d3ee61cedd8',
#    'commits': [{'sha': '5ab12b7a45accf4398767f87df485c7a888c047c',
#      'author': {'email': 'bot@trunk.io', 'name': 'trunk bot'},
#      'message': 'Moving words arenicolite',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/trunk-io/mergequeue-demo/commits/5ab12b7a45accf4398767f87df485c7a888c047c'},
#     {'sha': 'f9b2fa1f94ee75623f4762c5842ee385eeb66cfd',
#      'author': {'email': '87141165+trunk-staging-io[bot]@users.noreply.github.com',
#       'name': 'trunk-staging-io[bot]'},
#      'message': 'Merging 5ab12b7a45accf4398767f87df485c7a888c047c into trunk-temp/pr-19931/9b958378-b7e0-4d77-bba5-fec984cdb8a7',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/trunk-io/mergequeue-demo/commits/f9b2fa1f94ee75623f4762c5842ee385eeb66cfd'}]},
#   'public': True,
#   'created_at': '2025-07-25T02:17:21Z',
#   'org': {'id': 74779146,
#    'login': 'trunk-io',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/trunk-io',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/74779146?'}},
#  {'id': '52524724309',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 974435336,
#    'name': 'laplace-live/event-bridge',
#    'url': 'https://api.github.com/repos/laplace-live/event-bridge'},
#   'payload': {'action': 'closed',
#    'number': 62,
#    'pull_request': {'url': 'https://api.github.com/repos/laplace-live/event-bridge/pulls/62',
#     'id': 2675776145,
#     'node_id': 'PR_kwDOOhS0CM6ffRqR',
#     'html_url': 'https://github.com/laplace-live/event-bridge/pull/62',
#     'diff_url': 'https://github.com/laplace-live/event-bridge/pull/62.diff',
#     'patch_url': 'https://github.com/laplace-live/event-bridge/pull/62.patch',
#     'issue_url': 'https://api.github.com/repos/laplace-live/event-bridge/issues/62',
#     'number': 62,
#     'state': 'closed',
#     'locked': False,
#     'title': 'chore(deps-dev): bump vite from 6.3.5 to 7.0.5',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'body': "[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=vite&package-manager=bun&previous-version=6.3.5&new-version=7.0.5)](https://docs.github.com/en/github/managing-security-vulnerabilities/about-dependabot-security-updates#about-compatibility-scores)\n\nDependabot will resolve any conflicts with this PR as long as you don't alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot show <dependency name> ignore conditions` will show all of the ignore conditions of the specified dependency\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n\n\n</details>",
#     'created_at': '2025-07-18T02:08:46Z',
#     'updated_at': '2025-07-25T02:17:20Z',
#     'closed_at': '2025-07-25T02:17:20Z',
#     'merged_at': None,
#     'merge_commit_sha': 'dbf9adaf0aa5f7a562a40b524e115d732ab6caee',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 8557491628,
#       'node_id': 'LA_kwDOOhS0CM8AAAAB_hD1rA',
#       'url': 'https://api.github.com/repos/laplace-live/event-bridge/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'},
#      {'id': 8557491629,
#       'node_id': 'LA_kwDOOhS0CM8AAAAB_hD1rQ',
#       'url': 'https://api.github.com/repos/laplace-live/event-bridge/labels/javascript',
#       'name': 'javascript',
#       'color': '168700',
#       'default': False,
#       'description': 'Pull requests that update javascript code'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/laplace-live/event-bridge/pulls/62/commits',
#     'review_comments_url': 'https://api.github.com/repos/laplace-live/event-bridge/pulls/62/comments',
#     'review_comment_url': 'https://api.github.com/repos/laplace-live/event-bridge/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/laplace-live/event-bridge/issues/62/comments',
#     'statuses_url': 'https://api.github.com/repos/laplace-live/event-bridge/statuses/6bb6d65269734afc250953969bcf46dd1e6aed18',
#     'head': {'label': 'laplace-live:dependabot/bun/vite-7.0.5',
#      'ref': 'dependabot/bun/vite-7.0.5',
#      'sha': '6bb6d65269734afc250953969bcf46dd1e6aed18',
#      'user': {'login': 'laplace-live',
#       'id': 117213978,
#       'node_id': 'O_kgDOBvyLGg',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/117213978?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/laplace-live',
#       'html_url': 'https://github.com/laplace-live',
#       'followers_url': 'https://api.github.com/users/laplace-live/followers',
#       'following_url': 'https://api.github.com/users/laplace-live/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/laplace-live/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/laplace-live/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/laplace-live/subscriptions',
#       'organizations_url': 'https://api.github.com/users/laplace-live/orgs',
#       'repos_url': 'https://api.github.com/users/laplace-live/repos',
#       'events_url': 'https://api.github.com/users/laplace-live/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/laplace-live/received_events',
#       'type': 'Organization',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 974435336,
#       'node_id': 'R_kgDOOhS0CA',
#       'name': 'event-bridge',
#       'full_name': 'laplace-live/event-bridge',
#       'private': False,
#       'owner': {'login': 'laplace-live',
#        'id': 117213978,
#        'node_id': 'O_kgDOBvyLGg',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/117213978?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/laplace-live',
#        'html_url': 'https://github.com/laplace-live',
#        'followers_url': 'https://api.github.com/users/laplace-live/followers',
#        'following_url': 'https://api.github.com/users/laplace-live/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/laplace-live/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/laplace-live/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/laplace-live/subscriptions',
#        'organizations_url': 'https://api.github.com/users/laplace-live/orgs',
#        'repos_url': 'https://api.github.com/users/laplace-live/repos',
#        'events_url': 'https://api.github.com/users/laplace-live/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/laplace-live/received_events',
#        'type': 'Organization',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/laplace-live/event-bridge',
#       'description': 'A WebSocket bridge connecting LAPLACE Chat to clients',
#       'fork': False,
#       'url': 'https://api.github.com/repos/laplace-live/event-bridge',
#       'forks_url': 'https://api.github.com/repos/laplace-live/event-bridge/forks',
#       'keys_url': 'https://api.github.com/repos/laplace-live/event-bridge/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/laplace-live/event-bridge/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/laplace-live/event-bridge/teams',
#       'hooks_url': 'https://api.github.com/repos/laplace-live/event-bridge/hooks',
#       'issue_events_url': 'https://api.github.com/repos/laplace-live/event-bridge/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/laplace-live/event-bridge/events',
#       'assignees_url': 'https://api.github.com/repos/laplace-live/event-bridge/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/laplace-live/event-bridge/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/laplace-live/event-bridge/tags',
#       'blobs_url': 'https://api.github.com/repos/laplace-live/event-bridge/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/laplace-live/event-bridge/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/laplace-live/event-bridge/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/laplace-live/event-bridge/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/laplace-live/event-bridge/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/laplace-live/event-bridge/languages',
#       'stargazers_url': 'https://api.github.com/repos/laplace-live/event-bridge/stargazers',
#       'contributors_url': 'https://api.github.com/repos/laplace-live/event-bridge/contributors',
#       'subscribers_url': 'https://api.github.com/repos/laplace-live/event-bridge/subscribers',
#       'subscription_url': 'https://api.github.com/repos/laplace-live/event-bridge/subscription',
#       'commits_url': 'https://api.github.com/repos/laplace-live/event-bridge/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/laplace-live/event-bridge/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/laplace-live/event-bridge/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/laplace-live/event-bridge/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/laplace-live/event-bridge/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/laplace-live/event-bridge/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/laplace-live/event-bridge/merges',
#       'archive_url': 'https://api.github.com/repos/laplace-live/event-bridge/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/laplace-live/event-bridge/downloads',
#       'issues_url': 'https://api.github.com/repos/laplace-live/event-bridge/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/laplace-live/event-bridge/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/laplace-live/event-bridge/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/laplace-live/event-bridge/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/laplace-live/event-bridge/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/laplace-live/event-bridge/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/laplace-live/event-bridge/deployments',
#       'created_at': '2025-04-28T19:19:21Z',
#       'updated_at': '2025-07-22T18:14:23Z',
#       'pushed_at': '2025-07-25T02:17:18Z',
#       'git_url': 'git://github.com/laplace-live/event-bridge.git',
#       'ssh_url': 'git@github.com:laplace-live/event-bridge.git',
#       'clone_url': 'https://github.com/laplace-live/event-bridge.git',
#       'svn_url': 'https://github.com/laplace-live/event-bridge',
#       'homepage': 'https://subspace.institute/docs/laplace-chat/event-bridge',
#       'size': 1012,
#       'stargazers_count': 5,
#       'watchers_count': 5,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 5,
#       'license': {'key': 'agpl-3.0',
#        'name': 'GNU Affero General Public License v3.0',
#        'spdx_id': 'AGPL-3.0',
#        'url': 'https://api.github.com/licenses/agpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTE='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 5,
#       'watchers': 5,
#       'default_branch': 'master'}},
#     'base': {'label': 'laplace-live:master',
#      'ref': 'master',
#      'sha': '24cd27fb668ebd1edfcb2d89e68a010e4116c885',
#      'user': {'login': 'laplace-live',
#       'id': 117213978,
#       'node_id': 'O_kgDOBvyLGg',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/117213978?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/laplace-live',
#       'html_url': 'https://github.com/laplace-live',
#       'followers_url': 'https://api.github.com/users/laplace-live/followers',
#       'following_url': 'https://api.github.com/users/laplace-live/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/laplace-live/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/laplace-live/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/laplace-live/subscriptions',
#       'organizations_url': 'https://api.github.com/users/laplace-live/orgs',
#       'repos_url': 'https://api.github.com/users/laplace-live/repos',
#       'events_url': 'https://api.github.com/users/laplace-live/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/laplace-live/received_events',
#       'type': 'Organization',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 974435336,
#       'node_id': 'R_kgDOOhS0CA',
#       'name': 'event-bridge',
#       'full_name': 'laplace-live/event-bridge',
#       'private': False,
#       'owner': {'login': 'laplace-live',
#        'id': 117213978,
#        'node_id': 'O_kgDOBvyLGg',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/117213978?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/laplace-live',
#        'html_url': 'https://github.com/laplace-live',
#        'followers_url': 'https://api.github.com/users/laplace-live/followers',
#        'following_url': 'https://api.github.com/users/laplace-live/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/laplace-live/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/laplace-live/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/laplace-live/subscriptions',
#        'organizations_url': 'https://api.github.com/users/laplace-live/orgs',
#        'repos_url': 'https://api.github.com/users/laplace-live/repos',
#        'events_url': 'https://api.github.com/users/laplace-live/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/laplace-live/received_events',
#        'type': 'Organization',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/laplace-live/event-bridge',
#       'description': 'A WebSocket bridge connecting LAPLACE Chat to clients',
#       'fork': False,
#       'url': 'https://api.github.com/repos/laplace-live/event-bridge',
#       'forks_url': 'https://api.github.com/repos/laplace-live/event-bridge/forks',
#       'keys_url': 'https://api.github.com/repos/laplace-live/event-bridge/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/laplace-live/event-bridge/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/laplace-live/event-bridge/teams',
#       'hooks_url': 'https://api.github.com/repos/laplace-live/event-bridge/hooks',
#       'issue_events_url': 'https://api.github.com/repos/laplace-live/event-bridge/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/laplace-live/event-bridge/events',
#       'assignees_url': 'https://api.github.com/repos/laplace-live/event-bridge/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/laplace-live/event-bridge/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/laplace-live/event-bridge/tags',
#       'blobs_url': 'https://api.github.com/repos/laplace-live/event-bridge/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/laplace-live/event-bridge/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/laplace-live/event-bridge/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/laplace-live/event-bridge/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/laplace-live/event-bridge/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/laplace-live/event-bridge/languages',
#       'stargazers_url': 'https://api.github.com/repos/laplace-live/event-bridge/stargazers',
#       'contributors_url': 'https://api.github.com/repos/laplace-live/event-bridge/contributors',
#       'subscribers_url': 'https://api.github.com/repos/laplace-live/event-bridge/subscribers',
#       'subscription_url': 'https://api.github.com/repos/laplace-live/event-bridge/subscription',
#       'commits_url': 'https://api.github.com/repos/laplace-live/event-bridge/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/laplace-live/event-bridge/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/laplace-live/event-bridge/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/laplace-live/event-bridge/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/laplace-live/event-bridge/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/laplace-live/event-bridge/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/laplace-live/event-bridge/merges',
#       'archive_url': 'https://api.github.com/repos/laplace-live/event-bridge/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/laplace-live/event-bridge/downloads',
#       'issues_url': 'https://api.github.com/repos/laplace-live/event-bridge/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/laplace-live/event-bridge/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/laplace-live/event-bridge/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/laplace-live/event-bridge/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/laplace-live/event-bridge/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/laplace-live/event-bridge/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/laplace-live/event-bridge/deployments',
#       'created_at': '2025-04-28T19:19:21Z',
#       'updated_at': '2025-07-22T18:14:23Z',
#       'pushed_at': '2025-07-25T02:17:18Z',
#       'git_url': 'git://github.com/laplace-live/event-bridge.git',
#       'ssh_url': 'git@github.com:laplace-live/event-bridge.git',
#       'clone_url': 'https://github.com/laplace-live/event-bridge.git',
#       'svn_url': 'https://github.com/laplace-live/event-bridge',
#       'homepage': 'https://subspace.institute/docs/laplace-chat/event-bridge',
#       'size': 1012,
#       'stargazers_count': 5,
#       'watchers_count': 5,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 5,
#       'license': {'key': 'agpl-3.0',
#        'name': 'GNU Affero General Public License v3.0',
#        'spdx_id': 'AGPL-3.0',
#        'url': 'https://api.github.com/licenses/agpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTE='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 5,
#       'watchers': 5,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/laplace-live/event-bridge/pulls/62'},
#      'html': {'href': 'https://github.com/laplace-live/event-bridge/pull/62'},
#      'issue': {'href': 'https://api.github.com/repos/laplace-live/event-bridge/issues/62'},
#      'comments': {'href': 'https://api.github.com/repos/laplace-live/event-bridge/issues/62/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/laplace-live/event-bridge/pulls/62/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/laplace-live/event-bridge/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/laplace-live/event-bridge/pulls/62/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/laplace-live/event-bridge/statuses/6bb6d65269734afc250953969bcf46dd1e6aed18'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': True,
#     'mergeable_state': 'clean',
#     'merged_by': None,
#     'comments': 1,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 18,
#     'deletions': 12,
#     'changed_files': 3}},
#   'public': True,
#   'created_at': '2025-07-25T02:17:21Z',
#   'org': {'id': 117213978,
#    'login': 'laplace-live',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/laplace-live',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/117213978?'}},
#  {'id': '52524724333',
#   'type': 'PushEvent',
#   'actor': {'id': 194865069,
#    'login': 'OxySkyASH',
#    'display_login': 'OxySkyASH',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/OxySkyASH',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/194865069?'},
#   'repo': {'id': 934538568,
#    'name': 'OxySkyASH/web-profile',
#    'url': 'https://api.github.com/repos/OxySkyASH/web-profile'},
#   'payload': {'repository_id': 934538568,
#    'push_id': 25714272664,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '35cf0503d87fdff3200e6abc575119a82b50843b',
#    'before': 'b4249ad024baaee4b34cb279d1678e5bfac78348',
#    'commits': [{'sha': '35cf0503d87fdff3200e6abc575119a82b50843b',
#      'author': {'email': 'saoqhihidayat123@gmail.com', 'name': 'Saoqhi'},
#      'message': 'Update index.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/OxySkyASH/web-profile/commits/35cf0503d87fdff3200e6abc575119a82b50843b'}]},
#   'public': True,
#   'created_at': '2025-07-25T02:17:21Z'},
#  {'id': '52524724330',
#   'type': 'PushEvent',
#   'actor': {'id': 98244688,
#    'login': 'Jteoh99',
#    'display_login': 'Jteoh99',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Jteoh99',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/98244688?'},
#   'repo': {'id': 1021159008,
#    'name': 'Jteoh99/Arsenal',
#    'url': 'https://api.github.com/repos/Jteoh99/Arsenal'},
#   'payload': {'repository_id': 1021159008,
#    'push_id': 25714272680,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '68b6dda083c316eedffbc3d4f7d149f3e8c5ff91',
#    'before': '98c455c22675c89fb497a9408f46fa1b5a011df3',
#    'commits': [{'sha': '68b6dda083c316eedffbc3d4f7d149f3e8c5ff91',
#      'author': {'email': '98244688+Jteoh99@users.noreply.github.com',
#       'name': 'Jordan Teoh'},
#      'message': 'search bar and pagination',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Jteoh99/Arsenal/commits/68b6dda083c316eedffbc3d4f7d149f3e8c5ff91'}]},
#   'public': True,
#   'created_at': '2025-07-25T02:17:21Z'},
#  {'id': '52524724336',
#   'type': 'CreateEvent',
#   'actor': {'id': 54816060,
#    'login': 'pytorch-bot[bot]',
#    'display_login': 'pytorch-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pytorch-bot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54816060?'},
#   'repo': {'id': 65600975,
#    'name': 'pytorch/pytorch',
#    'url': 'https://api.github.com/repos/pytorch/pytorch'},
#   'payload': {'ref': 'ciflow/trunk/156652',
#    'ref_type': 'tag',
#    'master_branch': 'main',
#    'description': 'Tensors and Dynamic neural networks in Python with strong GPU acceleration',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-07-25T02:17:21Z',
#   'org': {'id': 21003710,
#    'login': 'pytorch',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/pytorch',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21003710?'}},
#  {'id': '52524724256',
#   'type': 'PushEvent',
#   'actor': {'id': 39824083,
#    'login': 'eru123',
#    'display_login': 'eru123',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eru123',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39824083?'},
#   'repo': {'id': 327367146,
#    'name': 'eru123/eru123',
#    'url': 'https://api.github.com/repos/eru123/eru123'},
#   'payload': {'repository_id': 327367146,
#    'push_id': 25714272643,
#    'size': 100,
#    'distinct_size': 100,
#    'ref': 'refs/heads/main',
#    'head': 'bbc55fb9896e09331825e07e19a0e7ea786ce7a2',
#    'before': '012d82e9d65a7f5d0499f646cfae0eb56da6baa0',
#    'commits': [{'sha': 'ec06b3da7de3e499f761b61ad6cc6da51b5060b7',
#      'author': {'email': 'jericho@skiddph.com', 'name': 'eru123'},
#      'message': '[BOT] Add random hash 351756ad68be',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/eru123/eru123/commits/ec06b3da7de3e499f761b61ad6cc6da51b5060b7'},
#     {'sha': 'fce00019b633ef46878a0f3d13ceddbd77bd3f22',
#      'author': {'email': 'jericho@skiddph.com', 'name': 'eru123'},
#      'message': '[BOT] Add random hash 4adb5ec3e35d',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/eru123/eru123/commits/fce00019b633ef46878a0f3d13ceddbd77bd3f22'},
#     {'sha': '328666ca562f202d43685eb625f725a799e1bc5f',
#      'author': {'email': 'jericho@skiddph.com', 'name': 'eru123'},
#      'message': '[BOT] Add random hash 43c68d2ac117',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/eru123/eru123/commits/328666ca562f202d43685eb625f725a799e1bc5f'},
#     {'sha': '16d370e1892f66eb6297b0619669eaef7b8bff69',
#      'author': {'email': 'jericho@skiddph.com', 'name': 'eru123'},
#      'message': '[BOT] Add random hash ea7d061f69a6',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/eru123/eru123/commits/16d370e1892f66eb6297b0619669eaef7b8bff69'},
#     {'sha': '622efd98822c9da25abb248492f8a5fae5666fef',
#      'author': {'email': 'jericho@skiddph.com', 'name': 'eru123'},
#      'message': '[BOT] Add random hash a1922198ca06',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/eru123/eru123/commits/622efd98822c9da25abb248492f8a5fae5666fef'},
#     {'sha': '9c3a9ead986a33ef555ccfe7339509aed32a7c3b',
#      'author': {'email': 'jericho@skiddph.com', 'name': 'eru123'},
#      'message': '[BOT] Add random hash e6f5aaa507cb',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/eru123/eru123/commits/9c3a9ead986a33ef555ccfe7339509aed32a7c3b'},
#     {'sha': '7c5532f620d1a56409a4e45f88b4157d660e6a6d',
#      'author': {'email': 'jericho@skiddph.com', 'name': 'eru123'},
#      'message': '[BOT] Add random hash 360c5aefb017',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/eru123/eru123/commits/7c5532f620d1a56409a4e45f88b4157d660e6a6d'},
#     {'sha': '4ac1558287e1799e7d1d9e3dbbafead436eab585',
#      'author': {'email': 'jericho@skiddph.com', 'name': 'eru123'},
#      'message': '[BOT] Add random hash 3f2e2d50161b',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/eru123/eru123/commits/4ac1558287e1799e7d1d9e3dbbafead436eab585'},
#     {'sha': '9b27241005245651333e2e563fbf700a0d13704b',
#      'author': {'email': 'jericho@skiddph.com', 'name': 'eru123'},
#      'message': '[BOT] Add random hash b42ed8c90d80',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/eru123/eru123/commits/9b27241005245651333e2e563fbf700a0d13704b'},
#     {'sha': '606637f31c4264f728964525bce5962f0d94c0aa',
#      'author': {'email': 'jericho@skiddph.com', 'name': 'eru123'},
#      'message': '[BOT] Add random hash a0975e595ee2',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/eru123/eru123/commits/606637f31c4264f728964525bce5962f0d94c0aa'},
#     {'sha': '49ccd063dba653bb5ab2a389b16089daa46f8151',
#      'author': {'email': 'jericho@skiddph.com', 'name': 'eru123'},
#      'message': '[BOT] Add random hash b49b82ad834b',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/eru123/eru123/commits/49ccd063dba653bb5ab2a389b16089daa46f8151'},
#     {'sha': '2c2b26e595b0916081ade36c81e4ef79254d0370',
#      'author': {'email': 'jericho@skiddph.com', 'name': 'eru123'},
#      'message': '[BOT] Add random hash 1228b65af4f8',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/eru123/eru123/commits/2c2b26e595b0916081ade36c81e4ef79254d0370'},
#     {'sha': '3bedd79dc6c5e2df4b4c31eb53e592df712d2e1d',
#      'author': {'email': 'jericho@skiddph.com', 'name': 'eru123'},
#      'message': '[BOT] Add random hash 861444585408',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/eru123/eru123/commits/3bedd79dc6c5e2df4b4c31eb53e592df712d2e1d'},
#     {'sha': '015c51f6ecd407a3636896fb0b64863a490b364a',
#      'author': {'email': 'jericho@skiddph.com', 'name': 'eru123'},
#      'message': '[BOT] Add random hash 01c01c3b2caa',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/eru123/eru123/commits/015c51f6ecd407a3636896fb0b64863a490b364a'},
#     {'sha': '258edca51634bab2b8ae40e515cb9dfb32ad098a',
#      'author': {'email': 'jericho@skiddph.com', 'name': 'eru123'},
#      'message': '[BOT] Add random hash 0e36534d6815',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/eru123/eru123/commits/258edca51634bab2b8ae40e515cb9dfb32ad098a'},
#     {'sha': 'cbed1b1a877f940cf1fcd98a328da484dc36bb59',
#      'author': {'email': 'jericho@skiddph.com', 'name': 'eru123'},
#      'message': '[BOT] Add random hash 0d6612c6823f',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/eru123/eru123/commits/cbed1b1a877f940cf1fcd98a328da484dc36bb59'},
#     {'sha': '775de97d853f8b96e231190600949f4d1d6ff335',
#      'author': {'email': 'jericho@skiddph.com', 'name': 'eru123'},
#      'message': '[BOT] Add random hash b49f1b0f176e',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/eru123/eru123/commits/775de97d853f8b96e231190600949f4d1d6ff335'},
#     {'sha': '07aa0167b6fbd51f9e33032f3e39f33456d7f372',
#      'author': {'email': 'jericho@skiddph.com', 'name': 'eru123'},
#      'message': '[BOT] Add random hash a4f6a52db847',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/eru123/eru123/commits/07aa0167b6fbd51f9e33032f3e39f33456d7f372'},
#     {'sha': 'd10a0108073acdc91b510c8add85c83f597d8481',
#      'author': {'email': 'jericho@skiddph.com', 'name': 'eru123'},
#      'message': '[BOT] Add random hash 90f3d52dbba7',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/eru123/eru123/commits/d10a0108073acdc91b510c8add85c83f597d8481'},
#     {'sha': 'c1ce9d92b8f7672b40d14dc0eab484f437430196',
#      'author': {'email': 'jericho@skiddph.com', 'name': 'eru123'},
#      'message': '[BOT] Add random hash 93a73825c1b7',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/eru123/eru123/commits/c1ce9d92b8f7672b40d14dc0eab484f437430196'}]},
#   'public': True,
#   'created_at': '2025-07-25T02:17:21Z'},
#  {'id': '52524724329',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 204318,
#    'login': 'gerdadecio',
#    'display_login': 'gerdadecio',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gerdadecio',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/204318?'},
#   'repo': {'id': 232973989,
#    'name': 'bio-org-au/editor',
#    'url': 'https://api.github.com/repos/bio-org-au/editor'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/bio-org-au/editor/pulls/comments/2229983012',
#     'pull_request_review_id': 3053886082,
#     'id': 2229983012,
#     'node_id': 'PRRC_kwDODeLmpc6E6tck',
#     'diff_hunk': '@@ -1,20 +1,75 @@\n+inherit_mode:\n+  merge:\n+    - Exclude\n+\n+inherit_gem:\n+  rubocop-shopify: rubocop.yml\n+\n+plugins:\n+  - rubocop-rails\n+  - rubocop-performance\n+\n+inherit_from:\n+  - .rubocop_strict.yml\n+\n AllCops:\n+  TargetRubyVersion: 3.3\n+  TargetRailsVersion: 7.1\n   NewCops: enable\n   Exclude:\n     - \'db/**/*\'\n-  TargetRubyVersion: 2.5\n+    - "config/**/*"\n+    - "bin/**/*"\n+\n+Rails/UniqueValidationWithoutIndex:\n+  Enabled: false\n+\n Style/TrailingCommaInArrayLiteral:\n   Enabled: false\n+\n Style/TrailingCommaInHashLiteral:\n-  Enabled: false\n+  EnforcedStyleForMultiline: consistent_comma',
#     'path': '.rubocop.yml',
#     'commit_id': 'd3daa2bd54742353bb2b9829b8d9b1efb1a0c29b',
#     'original_commit_id': 'd3daa2bd54742353bb2b9829b8d9b1efb1a0c29b',
#     'user': {'login': 'gerdadecio',
#      'id': 204318,
#      'node_id': 'MDQ6VXNlcjIwNDMxOA==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/204318?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/gerdadecio',
#      'html_url': 'https://github.com/gerdadecio',
#      'followers_url': 'https://api.github.com/users/gerdadecio/followers',
#      'following_url': 'https://api.github.com/users/gerdadecio/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/gerdadecio/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/gerdadecio/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/gerdadecio/subscriptions',
#      'organizations_url': 'https://api.github.com/users/gerdadecio/orgs',
#      'repos_url': 'https://api.github.com/users/gerdadecio/repos',
#      'events_url': 'https://api.github.com/users/gerdadecio/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/gerdadecio/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'body': 'no we are enforcing traling comman here\r\n```\r\n# Good - has trailing comma\r\nhash = {\r\n  foo: 1,\r\n  bar: 2,\r\n  baz: 3,\r\n}\r\n\r\n# Bad - missing trailing comma\r\nhash = {\r\n  foo: 1,\r\n  bar: 2,\r\n  baz: 3\r\n}\r\n```',
#     'created_at': '2025-07-25T02:17:20Z',
#     'updated_at': '2025-07-25T02:17:20Z',
#     'html_url': 'https://github.com/bio-org-au/editor/pull/452#discussion_r2229983012',
#     'pull_request_url': 'https://api.github.com/repos/bio-org-au/editor/pulls/452',
#     'author_association': 'CONTRIBUTOR',
#     '_links': {'self': {'href': 'https://api.github.com/repos/bio-org-au/editor/pulls/comments/2229983012'},
#      'html': {'href': 'https://github.com/bio-org-au/editor/pull/452#discussion_r2229983012'},
#      'pull_request': {'href': 'https://api.github.com/repos/bio-org-au/editor/pulls/452'}},
#     'reactions': {'url': 'https://api.github.com/repos/bio-org-au/editor/pulls/comments/2229983012/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'start_line': None,
#     'original_start_line': None,
#     'start_side': None,
#     'line': 31,
#     'original_line': 31,
#     'side': 'RIGHT',
#     'in_reply_to_id': 2229929182,
#     'original_position': 33,
#     'position': 33,
#     'subject_type': 'line'},
#    'pull_request': {'url': 'https://api.github.com/repos/bio-org-au/editor/pulls/452',
#     'id': 2693558743,
#     'node_id': 'PR_kwDODeLmpc6gjHHX',
#     'html_url': 'https://github.com/bio-org-au/editor/pull/452',
#     'diff_url': 'https://github.com/bio-org-au/editor/pull/452.diff',
#     'patch_url': 'https://github.com/bio-org-au/editor/pull/452.patch',
#     'issue_url': 'https://api.github.com/repos/bio-org-au/editor/issues/452',
#     'number': 452,
#     'state': 'open',
#     'locked': False,
#     'title': 'Rubocop rules',
#     'user': {'login': 'gerdadecio',
#      'id': 204318,
#      'node_id': 'MDQ6VXNlcjIwNDMxOA==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/204318?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/gerdadecio',
#      'html_url': 'https://github.com/gerdadecio',
#      'followers_url': 'https://api.github.com/users/gerdadecio/followers',
#      'following_url': 'https://api.github.com/users/gerdadecio/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/gerdadecio/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/gerdadecio/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/gerdadecio/subscriptions',
#      'organizations_url': 'https://api.github.com/users/gerdadecio/orgs',
#      'repos_url': 'https://api.github.com/users/gerdadecio/repos',
#      'events_url': 'https://api.github.com/users/gerdadecio/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/gerdadecio/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'body': '## Description\r\nRubocop rules and enforce it on file save for vscode editor\r\n\r\n## Type of change\r\n- [x] New feature (non-breaking change which adds functionality)\r\n\r\n## Pre-merge steps\r\n- [ ] Bumped version\r\n- [ ] Updated changelog (Please add an entry to the changelog for the current year)\r\n',
#     'created_at': '2025-07-25T01:06:37Z',
#     'updated_at': '2025-07-25T02:17:20Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': 'b6762fa4970eb7dca7acd9085cabd69bca568c17',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/bio-org-au/editor/pulls/452/commits',
#     'review_comments_url': 'https://api.github.com/repos/bio-org-au/editor/pulls/452/comments',
#     'review_comment_url': 'https://api.github.com/repos/bio-org-au/editor/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/bio-org-au/editor/issues/452/comments',
#     'statuses_url': 'https://api.github.com/repos/bio-org-au/editor/statuses/d3daa2bd54742353bb2b9829b8d9b1efb1a0c29b',
#     'head': {'label': 'gerdadecio:chore/rubocop-rules',
#      'ref': 'chore/rubocop-rules',
#      'sha': 'd3daa2bd54742353bb2b9829b8d9b1efb1a0c29b',
#      'user': {'login': 'gerdadecio',
#       'id': 204318,
#       'node_id': 'MDQ6VXNlcjIwNDMxOA==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/204318?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/gerdadecio',
#       'html_url': 'https://github.com/gerdadecio',
#       'followers_url': 'https://api.github.com/users/gerdadecio/followers',
#       'following_url': 'https://api.github.com/users/gerdadecio/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/gerdadecio/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/gerdadecio/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/gerdadecio/subscriptions',
#       'organizations_url': 'https://api.github.com/users/gerdadecio/orgs',
#       'repos_url': 'https://api.github.com/users/gerdadecio/repos',
#       'events_url': 'https://api.github.com/users/gerdadecio/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/gerdadecio/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 861465606,
#       'node_id': 'R_kgDOM1jsBg',
#       'name': 'nsl-editor',
#       'full_name': 'gerdadecio/nsl-editor',
#       'private': False,
#       'owner': {'login': 'gerdadecio',
#        'id': 204318,
#        'node_id': 'MDQ6VXNlcjIwNDMxOA==',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/204318?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/gerdadecio',
#        'html_url': 'https://github.com/gerdadecio',
#        'followers_url': 'https://api.github.com/users/gerdadecio/followers',
#        'following_url': 'https://api.github.com/users/gerdadecio/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/gerdadecio/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/gerdadecio/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/gerdadecio/subscriptions',
#        'organizations_url': 'https://api.github.com/users/gerdadecio/orgs',
#        'repos_url': 'https://api.github.com/users/gerdadecio/repos',
#        'events_url': 'https://api.github.com/users/gerdadecio/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/gerdadecio/received_events',
#        'type': 'User',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/gerdadecio/nsl-editor',
# ...
#       'git_tags_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/languages',
#       'stargazers_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/stargazers',
#       'contributors_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/contributors',
#       'subscribers_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/subscribers',
#       'subscription_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/subscription',
#       'commits_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/merges',
#       'archive_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/downloads',
#       'issues_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/deployments',
#       'created_at': '2011-12-09T00:43:19Z',
#       'updated_at': '2025-07-24T21:49:21Z',
#       'pushed_at': '2025-07-25T02:15:25Z',
#       'git_url': 'git://github.com/wiredtiger/wiredtiger.git',
#       'ssh_url': 'git@github.com:wiredtiger/wiredtiger.git',
#       'clone_url': 'https://github.com/wiredtiger/wiredtiger.git',
#       'svn_url': 'https://github.com/wiredtiger/wiredtiger',
#       'homepage': 'http://source.wiredtiger.com/',
#       'size': 173250,
#       'stargazers_count': 2309,
#       'watchers_count': 2309,
#       'language': 'C',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 406,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 52,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['hacktoberfest'],
#       'visibility': 'public',
#       'forks': 406,
#       'open_issues': 52,
#       'watchers': 2309,
#       'default_branch': 'develop'}},
#     'base': {'label': 'wiredtiger:wiredtiger-disagg-integration',
#      'ref': 'wiredtiger-disagg-integration',
#      'sha': '65da7cbaa2f64cbc56a6b54a3ba3e891e6a259c7',
#      'user': {'login': 'wiredtiger',
#       'id': 1251095,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEyNTEwOTU=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/1251095?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/wiredtiger',
#       'html_url': 'https://github.com/wiredtiger',
#       'followers_url': 'https://api.github.com/users/wiredtiger/followers',
#       'following_url': 'https://api.github.com/users/wiredtiger/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/wiredtiger/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/wiredtiger/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/wiredtiger/subscriptions',
#       'organizations_url': 'https://api.github.com/users/wiredtiger/orgs',
#       'repos_url': 'https://api.github.com/users/wiredtiger/repos',
#       'events_url': 'https://api.github.com/users/wiredtiger/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/wiredtiger/received_events',
#       'type': 'Organization',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 2944302,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyOTQ0MzAy',
#       'name': 'wiredtiger',
#       'full_name': 'wiredtiger/wiredtiger',
#       'private': False,
#       'owner': {'login': 'wiredtiger',
#        'id': 1251095,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEyNTEwOTU=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/1251095?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/wiredtiger',
#        'html_url': 'https://github.com/wiredtiger',
#        'followers_url': 'https://api.github.com/users/wiredtiger/followers',
#        'following_url': 'https://api.github.com/users/wiredtiger/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/wiredtiger/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/wiredtiger/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/wiredtiger/subscriptions',
#        'organizations_url': 'https://api.github.com/users/wiredtiger/orgs',
#        'repos_url': 'https://api.github.com/users/wiredtiger/repos',
#        'events_url': 'https://api.github.com/users/wiredtiger/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/wiredtiger/received_events',
#        'type': 'Organization',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/wiredtiger/wiredtiger',
#       'description': "WiredTiger's source tree",
#       'fork': False,
#       'url': 'https://api.github.com/repos/wiredtiger/wiredtiger',
#       'forks_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/forks',
#       'keys_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/teams',
#       'hooks_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/hooks',
#       'issue_events_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/events',
#       'assignees_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/tags',
#       'blobs_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/languages',
#       'stargazers_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/stargazers',
#       'contributors_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/contributors',
#       'subscribers_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/subscribers',
#       'subscription_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/subscription',
#       'commits_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/merges',
#       'archive_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/downloads',
#       'issues_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/wiredtiger/wiredtiger/deployments',
#       'created_at': '2011-12-09T00:43:19Z',
#       'updated_at': '2025-07-24T21:49:21Z',
#       'pushed_at': '2025-07-25T02:15:25Z',
#       'git_url': 'git://github.com/wiredtiger/wiredtiger.git',
#       'ssh_url': 'git@github.com:wiredtiger/wiredtiger.git',
#       'clone_url': 'https://github.com/wiredtiger/wiredtiger.git',
#       'svn_url': 'https://github.com/wiredtiger/wiredtiger',
#       'homepage': 'http://source.wiredtiger.com/',
#       'size': 173250,
#       'stargazers_count': 2309,
#       'watchers_count': 2309,
#       'language': 'C',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 406,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 52,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['hacktoberfest'],
#       'visibility': 'public',
#       'forks': 406,
#       'open_issues': 52,
#       'watchers': 2309,
#       'default_branch': 'develop'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/wiredtiger/wiredtiger/pulls/12158'},
#      'html': {'href': 'https://github.com/wiredtiger/wiredtiger/pull/12158'},
#      'issue': {'href': 'https://api.github.com/repos/wiredtiger/wiredtiger/issues/12158'},
#      'comments': {'href': 'https://api.github.com/repos/wiredtiger/wiredtiger/issues/12158/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/wiredtiger/wiredtiger/pulls/12158/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/wiredtiger/wiredtiger/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/wiredtiger/wiredtiger/pulls/12158/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/wiredtiger/wiredtiger/statuses/13e400d9c3bbe9f570b350692d05b01df1a85240'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'jiechenbo',
#      'id': 29520270,
#      'node_id': 'MDQ6VXNlcjI5NTIwMjcw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/29520270?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jiechenbo',
#      'html_url': 'https://github.com/jiechenbo',
#      'followers_url': 'https://api.github.com/users/jiechenbo/followers',
#      'following_url': 'https://api.github.com/users/jiechenbo/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jiechenbo/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jiechenbo/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jiechenbo/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jiechenbo/orgs',
#      'repos_url': 'https://api.github.com/users/jiechenbo/repos',
#      'events_url': 'https://api.github.com/users/jiechenbo/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jiechenbo/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'comments': 2,
#     'review_comments': 20,
#     'maintainer_can_modify': False,
#     'commits': 19,
#     'additions': 895,
#     'deletions': 592,
#     'changed_files': 11}},
#   'public': True,
#   'created_at': '2025-07-25T02:17:21Z',
#   'org': {'id': 1251095,
#    'login': 'wiredtiger',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/wiredtiger',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1251095?'}},
#  {'id': '52524724153',
#   'type': 'PushEvent',
#   'actor': {'id': 166895733,
#    'login': 'swa-runner-app[bot]',
#    'display_login': 'swa-runner-app',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/swa-runner-app[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/166895733?'},
#   'repo': {'id': 1025903472,
#    'name': 'static-web-apps-testing-org/swa28e0f8681af749b0af39a1d70a7f87c5',
#    'url': 'https://api.github.com/repos/static-web-apps-testing-org/swa28e0f8681af749b0af39a1d70a7f87c5'},
#   'payload': {'repository_id': 1025903472,
#    'push_id': 25714272610,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd0b42de973c7d8ee76b2619f28b8017735001a1c',
#    'before': '7b79a2da52a69437cbeb5fc8b0e4bf8fe9457e61',
#    'commits': [{'sha': 'd0b42de973c7d8ee76b2619f28b8017735001a1c',
#      'author': {'email': '166895733+swa-runner-app[bot]@users.noreply.github.com',
#       'name': 'swa-runner-app[bot]'},
#      'message': 'Writing file e2e/src/app.po.ts',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/static-web-apps-testing-org/swa28e0f8681af749b0af39a1d70a7f87c5/commits/d0b42de973c7d8ee76b2619f28b8017735001a1c'}]},
#   'public': True,
#   'created_at': '2025-07-25T02:17:21Z',
#   'org': {'id': 96167003,
#    'login': 'static-web-apps-testing-org',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/static-web-apps-testing-org',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/96167003?'}},
#  {'id': '52524724150',
#   'type': 'PushEvent',
#   'actor': {'id': 19688908,
#    'login': 'zomeru',
#    'display_login': 'zomeru',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zomeru',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19688908?'},
#   'repo': {'id': 356011647,
#    'name': 'zomeru/zomeru',
#    'url': 'https://api.github.com/repos/zomeru/zomeru'},
#   'payload': {'repository_id': 356011647,
#    'push_id': 25714272614,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '4b63e2dbd9e794141030a9128c63556a326cddb4',
#    'before': 'c02d13e361f41d88019a74efd1073aa77c63b83c',
#    'commits': [{'sha': '4b63e2dbd9e794141030a9128c63556a326cddb4',
#      'author': {'email': 'None', 'name': 'zomeru'},
#      'message': 'Update readme',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/zomeru/zomeru/commits/4b63e2dbd9e794141030a9128c63556a326cddb4'}]},
#   'public': True,
#   'created_at': '2025-07-25T02:17:21Z'}]

# %%
r = requests.post('https://httpbin.org/post', data = payload)

# %%
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key1": "value1",
#     "key2": "value2"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "23",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.3",
#     "X-Amzn-Trace-Id": "Root=1-6882eef3-28b315fb5f24128d627c04c5"
#   },
#   "json": null,
#   "origin": "223.227.79.71",
#   "url": "https://httpbin.org/post"
# }

# %%
requests.codes.ok
# Out:
# 200

# %%
print(r.headers['Content-Type'])
# Out:
# application/json
