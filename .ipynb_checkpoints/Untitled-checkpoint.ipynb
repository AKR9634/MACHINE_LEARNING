# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Airlinedelaycause.csv")

# %%
df
# Out:
#         year  month carrier            carrier_name airport  \
# 0       2023     12      9E       Endeavor Air Inc.     ABE
# 1       2023     12      9E       Endeavor Air Inc.     AEX
# 2       2023     12      9E       Endeavor Air Inc.     AGS
# 3       2023     12      9E       Endeavor Air Inc.     ALB
# 4       2023     12      9E       Endeavor Air Inc.     ATL
# ...      ...    ...     ...                     ...     ...
# 179333  2015      1      WN  Southwest Airlines Co.     ONT
# 179334  2015      1      WN  Southwest Airlines Co.     ORF
# 179335  2015      1      WN  Southwest Airlines Co.     PBI
# 179336  2015      1      WN  Southwest Airlines Co.     PDX
# 179337  2015      1      WN  Southwest Airlines Co.     PHL
#
#                                              airport_name  arr_flights  \
# 0       Allentown/Bethlehem/Easton, PA: Lehigh Valley ...         72.0
# 1                Alexandria, LA: Alexandria International         62.0
# ...

# %%
df.head()
# Out:
#    year  month carrier       carrier_name airport  \
# 0  2023     12      9E  Endeavor Air Inc.     ABE
# 1  2023     12      9E  Endeavor Air Inc.     AEX
# 2  2023     12      9E  Endeavor Air Inc.     AGS
# 3  2023     12      9E  Endeavor Air Inc.     ALB
# 4  2023     12      9E  Endeavor Air Inc.     ATL
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...         72.0        5.0
# 1           Alexandria, LA: Alexandria International         62.0        7.0
# 2        Augusta, GA: Augusta Regional at Bush Field         95.0       10.0
# 3                   Albany, NY: Albany International         23.0        2.0
# 4  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...       2111.0      256.0
#
#    carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  arr_cancelled  \
# 0        2.46        1.00  ...          0.0              0.81            0.0
# ...

# %%
df['carrier'].unique()
# Out:
# array(['9E', 'AA', 'OH', 'OO', 'WN', 'AS', 'DL', 'PT', 'QX', 'UA', 'YV',
#        'B6', 'F9', 'G4', 'G7', 'HA', 'MQ', 'YX', 'ZW', 'C5', 'NK', 'EM',
#        'EV', 'AX', 'CP', 'KS', '9K', 'VX', 'US'], dtype=object)

# %%
df['carrier'].unique().size
# Out:
# 29

# %%
df['carrier_name'].unique()
# Out:
# array(['Endeavor Air Inc.', 'American Airlines Network',
#        'PSA Airlines Inc.', 'SkyWest Airlines Inc.', 'Southwest Airlines',
#        'Alaska Airlines Network', 'Delta Air Lines Network',
#        'Piedmont Airlines', 'Horizon Air', 'United Air Lines Network',
#        'Mesa Airlines Inc.', 'JetBlue Airways', 'Frontier Airlines',
#        'Allegiant Air', 'GoJet Airlines LLC d/b/a United Express',
#        'Hawaiian Airlines Network', 'Envoy Air', 'Republic Airline',
#        'Air Wisconsin Airlines Corp', 'CommuteAir LLC dba CommuteAir',
#        'Spirit Airlines', 'Commutair Aka Champlain Enterprises, Inc.',
#        'Empire Airlines Inc.', 'ExpressJet Airlines LLC',
#        'Trans States Airlines', 'Compass Airlines',
#        'Peninsula Airways Inc.', 'ExpressJet Airlines Inc.', 'Cape Air',
#        'Virgin America', 'American Airlines Inc.', 'Alaska Airlines Inc.',
#        'Delta Air Lines Inc.', 'United Air Lines Inc.',
# ...

# %%
df['carrier_name'].unique().size
# Out:
# 39

# %%
df.groupby(['carrier', 'carrier_name']).count()
# Out:
#                                                     year  month  airport  \
# carrier carrier_name
# 9E      Endeavor Air Inc.                           7494   7494     7494
# 9K      Cape Air                                      15     15       15
# AA      American Airlines Inc.                      3258   3258     3258
#         American Airlines Network                   7654   7654     7654
# AS      Alaska Airlines Inc.                        2321   2321     2321
#         Alaska Airlines Network                     5433   5433     5433
# AX      Trans States Airlines                       1932   1932     1932
# B6      JetBlue Airways                             6827   6827     6827
# C5      Commutair Aka Champlain Enterprises, Inc.   2646   2646     2646
#         CommuteAir LLC dba CommuteAir                784    784      784
# CP      Compass Airlines                             926    926      926
# ...

# %%
df['airport'].unique().size
# Out:
# 396

# %%
df['airport_name'].unique().size
# Out:
# 420

# %%
idx = df.index[df['carrier'] == 'AA']

# %%
idx
# Out:
# Index([   110,    111,    112,    113,    114,    115,    116,    117,    118,
#           119,
#        ...
#        178234, 178235, 178236, 178237, 178238, 178239, 178240, 178241, 178242,
#        178243],
#       dtype='int64', length=10912)

# %%
df['carrier_name'].loc[idx].unique()
# Out:
# array(['American Airlines Network', 'American Airlines Inc.'],
#       dtype=object)

# %%
df.isna()
# Out:
#          year  month  carrier  carrier_name  airport  airport_name  \
# 0       False  False    False         False    False         False
# 1       False  False    False         False    False         False
# 2       False  False    False         False    False         False
# 3       False  False    False         False    False         False
# 4       False  False    False         False    False         False
# ...       ...    ...      ...           ...      ...           ...
# 179333  False  False    False         False    False         False
# 179334  False  False    False         False    False         False
# 179335  False  False    False         False    False         False
# 179336  False  False    False         False    False         False
# 179337  False  False    False         False    False         False
#
#         arr_flights  arr_del15  carrier_ct  weather_ct  ...  security_ct  \
# 0             False      False       False       False  ...        False
# ...

# %%
df.isnull()
# Out:
#          year  month  carrier  carrier_name  airport  airport_name  \
# 0       False  False    False         False    False         False
# 1       False  False    False         False    False         False
# 2       False  False    False         False    False         False
# 3       False  False    False         False    False         False
# 4       False  False    False         False    False         False
# ...       ...    ...      ...           ...      ...           ...
# 179333  False  False    False         False    False         False
# 179334  False  False    False         False    False         False
# 179335  False  False    False         False    False         False
# 179336  False  False    False         False    False         False
# 179337  False  False    False         False    False         False
#
#         arr_flights  arr_del15  carrier_ct  weather_ct  ...  security_ct  \
# 0             False      False       False       False  ...        False
# ...

# %%
df.size
# Out:
# 3766098

# %%
df.shape
# Out:
# (179338, 21)

# %%
df[df['arr_del15'].isnull()]
# Out:
#         year  month carrier                             carrier_name airport  \
# 779     2023     12      UA                 United Air Lines Network     BHM
# 1254    2023     12      G7  GoJet Airlines LLC d/b/a United Express     SBN
# 1423    2023     12      YV                       Mesa Airlines Inc.     ROA
# 1470    2023     12      YX                         Republic Airline     ICT
# 2278    2023     11      C5            CommuteAir LLC dba CommuteAir     BTV
# ...      ...    ...     ...                                      ...     ...
# 176507  2015      3      MQ                                Envoy Air     GUC
# 176725  2015      3      OO                    SkyWest Airlines Inc.     EWR
# 176825  2015      3      UA                    United Air Lines Inc.     STL
# 178668  2015      1      EV                 ExpressJet Airlines Inc.     PHX
# 179059  2015      1      OO                    SkyWest Airlines Inc.     EVV
#
# ...

# %%
df.iloc[779]
# Out:
# year                                                                2023
# month                                                                 12
# carrier                                                               UA
# carrier_name                                    United Air Lines Network
# airport                                                              BHM
# airport_name           Birmingham, AL: Birmingham-Shuttlesworth Inter...
# arr_flights                                                          NaN
# arr_del15                                                            NaN
# carrier_ct                                                           NaN
# weather_ct                                                           NaN
# nas_ct                                                               NaN
# security_ct                                                          NaN
# late_aircraft_ct                                                     NaN
# ...
