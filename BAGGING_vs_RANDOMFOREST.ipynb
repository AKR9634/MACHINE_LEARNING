# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
X, y = make_classification(n_features = 5, n_redundant= 0, n_informative= 5, n_clusters_per_class=1)

# %%
df = pd.DataFrame(X, columns=['col1', 'col2', 'col3', 'col4', 'col5'])
df['target'] = y
print(df.shape)
df.head
# Out:
# (100, 6)
# <bound method NDFrame.head of         col1      col2      col3      col4      col5  target
# 0  -0.062113  2.700649 -0.556233  3.665481  1.373959       1
# 1   0.718981  0.733423  0.482295 -1.091513 -1.162704       0
# 2   2.171670  1.244258 -0.398881  0.907147 -0.281940       1
# 3   3.384817 -4.050466  2.330145  1.299822 -3.634601       0
# 4   1.844326  1.657544  2.101252  0.037838  1.413683       1
# ..       ...       ...       ...       ...       ...     ...
# 95  0.187229 -4.005799  2.687936 -2.099344 -1.000013       0
# 96  0.432398  2.175356  0.398528  1.766263  2.483768       1
# 97 -0.942320 -0.396971  0.408656  2.261609  1.665564       1
# 98 -1.282507 -3.114176  2.422992 -2.896305  0.478008       0
# 99  0.898793 -0.786647  2.373687  0.611881  0.525943       1
#
# [100 rows x 6 columns]>

# %%
df
# Out:
#         col1      col2      col3      col4      col5  target
# 0  -0.062113  2.700649 -0.556233  3.665481  1.373959       1
# 1   0.718981  0.733423  0.482295 -1.091513 -1.162704       0
# 2   2.171670  1.244258 -0.398881  0.907147 -0.281940       1
# 3   3.384817 -4.050466  2.330145  1.299822 -3.634601       0
# 4   1.844326  1.657544  2.101252  0.037838  1.413683       1
# ..       ...       ...       ...       ...       ...     ...
# 95  0.187229 -4.005799  2.687936 -2.099344 -1.000013       0
# 96  0.432398  2.175356  0.398528  1.766263  2.483768       1
# 97 -0.942320 -0.396971  0.408656  2.261609  1.665564       1
# 98 -1.282507 -3.114176  2.422992 -2.896305  0.478008       0
# 99  0.898793 -0.786647  2.373687  0.611881  0.525943       1
#
# [100 rows x 6 columns]

# %%
bag = BaggingClassifier(max_features=2)

# %%
bag.fit(df.iloc[:, :5], df.iloc[:, -1])
# Out:
# BaggingClassifier(max_features=2)

# %%
plt.figure(figsize = (12, 12))
plot_tree(bag.estimators_[0])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
bag.estimators_features_
# Out:
# [array([3, 4], dtype=int32),
#  array([4, 0], dtype=int32),
#  array([4, 0], dtype=int32),
#  array([1, 0], dtype=int32),
#  array([2, 0], dtype=int32),
#  array([1, 0], dtype=int32),
#  array([2, 3], dtype=int32),
#  array([4, 2], dtype=int32),
#  array([2, 4], dtype=int32),
#  array([4, 1], dtype=int32)]

# %%
plot_tree(bag.estimators_[3])
# Out:
# [Text(0.3125, 0.9583333333333334, 'x[0] <= 1.15\ngini = 0.497\nsamples = 61\nvalue = [46, 54]'),
#  Text(0.2625, 0.875, 'x[0] <= -1.827\ngini = 0.444\nsamples = 41\nvalue = [46, 23]'),
#  Text(0.2875, 0.9166666666666667, 'True  '),
#  Text(0.2125, 0.7916666666666666, 'gini = 0.0\nsamples = 7\nvalue = [14, 0]'),
#  Text(0.3125, 0.7916666666666666, 'x[1] <= -0.586\ngini = 0.487\nsamples = 34\nvalue = [32, 23]'),
#  Text(0.15, 0.7083333333333334, 'x[0] <= -0.397\ngini = 0.153\nsamples = 6\nvalue = [11, 1]'),
#  Text(0.1, 0.625, 'x[0] <= -0.707\ngini = 0.375\nsamples = 3\nvalue = [3, 1]'),
#  Text(0.05, 0.5416666666666666, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]'),
#  Text(0.15, 0.5416666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2, 0.625, 'gini = 0.0\nsamples = 3\nvalue = [8, 0]'),
#  Text(0.475, 0.7083333333333334, 'x[1] <= 0.159\ngini = 0.5\nsamples = 28\nvalue = [21, 22]'),
#  Text(0.3, 0.625, 'x[1] <= 0.032\ngini = 0.142\nsamples = 8\nvalue = [1, 12]'),
#  Text(0.25, 0.5416666666666666, 'gini = 0.0\nsamples = 6\nvalue = [0, 10]'),
#  Text(0.35, 0.5416666666666666, 'x[1] <= 0.108\ngini = 0.444\nsamples = 2\nvalue = [1, 2]'),
#  Text(0.3, 0.4583333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4, 0.4583333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]'),
#  Text(0.65, 0.625, 'x[1] <= 1.516\ngini = 0.444\nsamples = 20\nvalue = [20, 10]'),
#  Text(0.6, 0.5416666666666666, 'x[0] <= -0.552\ngini = 0.486\nsamples = 16\nvalue = [14, 10]'),
#  Text(0.5, 0.4583333333333333, 'x[0] <= -0.919\ngini = 0.298\nsamples = 8\nvalue = [9, 2]'),
#  Text(0.45, 0.375, 'x[1] <= 0.666\ngini = 0.48\nsamples = 4\nvalue = [3, 2]'),
#  Text(0.4, 0.2916666666666667, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(0.5, 0.2916666666666667, 'x[0] <= -1.174\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.45, 0.20833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.55, 0.20833333333333334, 'x[0] <= -0.994\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.55, 0.375, 'gini = 0.0\nsamples = 4\nvalue = [6, 0]'),
#  Text(0.7, 0.4583333333333333, 'x[1] <= 0.359\ngini = 0.473\nsamples = 8\nvalue = [5, 8]'),
#  Text(0.65, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]'),
#  Text(0.75, 0.375, 'x[0] <= -0.327\ngini = 0.32\nsamples = 6\nvalue = [2, 8]'),
#  Text(0.7, 0.2916666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 5]'),
#  Text(0.8, 0.2916666666666667, 'x[0] <= -0.121\ngini = 0.48\nsamples = 4\nvalue = [2, 3]'),
#  Text(0.75, 0.20833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.85, 0.20833333333333334, 'x[0] <= 0.392\ngini = 0.375\nsamples = 3\nvalue = [1, 3]'),
#  Text(0.8, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]'),
#  Text(0.9, 0.125, 'x[1] <= 0.561\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.85, 0.041666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.95, 0.041666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7, 0.5416666666666666, 'gini = 0.0\nsamples = 4\nvalue = [6, 0]'),
#  Text(0.3625, 0.875, 'gini = 0.0\nsamples = 20\nvalue = [0, 31]'),
#  Text(0.3375, 0.9166666666666667, '  False')]

# %%
rfr = RandomForestClassifier(max_features = 2)

# %%
rfr.fit(df.iloc[:, :5], df.iloc[:, -1])
# Out:
# RandomForestClassifier(max_features=2)

# %%
plt.figure(figsize = (12, 12))
plot_tree(rfr.estimators_[4])
plt.show()
