# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.datasets import load_iris

# %%
iris=load_iris()
X,y=load_iris(return_X_y=True)
features=iris.feature_names

# %%
X=pd.DataFrame(X,columns=features)

# %%
X.head(5)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
x_train,x_test,y_train ,y_test=train_test_split(X,y,test_size=.2,random_state=41)
scaler=StandardScaler()

# %%
x_train
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 79                 5.7               2.6                3.5               1.0
# 54                 6.5               2.8                4.6               1.5
# 106                4.9               2.5                4.5               1.7
# 90                 5.5               2.6                4.4               1.2
# 145                6.7               3.0                5.2               2.3
# ..                 ...               ...                ...               ...
# 26                 5.0               3.4                1.6               0.4
# 89                 5.5               2.5                4.0               1.3
# 65                 6.7               3.1                4.4               1.4
# 80                 5.5               2.4                3.8               1.1
# 140                6.7               3.1                5.6               2.4
#
# [120 rows x 4 columns]

# %%
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
mlp=MLPClassifier(hidden_layer_sizes=(6,5),max_iter=10000,random_state=42)
mlp.fit(x_train,y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(6, 5), max_iter=10000, random_state=42)

# %%
y_pred=mlp.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print("the accuracy score of the mlp model is :",accuracy_score(y_test,y_pred))
# Out:
# the accuracy score of the mlp model is : 0.9

# %%
plt.scatter(X.iloc[:, 0], y, c = y, cmap='viridis')
